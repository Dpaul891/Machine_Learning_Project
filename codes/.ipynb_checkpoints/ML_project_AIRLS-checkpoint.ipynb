# %%
from PIL import Image
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm
import os
from scipy.sparse import csr_matrix
from scipy.sparse import diags

# %%
d = n = 50
r = 5
U_star = np.random.normal(0, 1, (d, r))
V_star = np.random.normal(0, 1, (n, r))
L_star = U_star.dot(V_star.T)
L_star.shape
# Out:
# (50, 50)

# %%
def create_S(p,d,n):
    s = np.zeros(d*n)

    change_list = random.sample(range(d*n),int(p*d*n))
    for i in change_list:
        s[i] = np.random.normal(0, 10)
    
    s = s.reshape(d,n)
    return s

# %%
def L1_norm(x):
    return np.sum(np.abs(x))

# %%
def fun_val(x, u, v):
    return L1_norm(x-np.dot(u, v.T))

# %%
def plt_converge(norm_list):
    x = range(len(norm_list))
    plt.plot(x, norm_list)
    plt.xlabel("iteration number")
    plt.ylabel(r"$||U_kV_k^{T}-L^{\star}||_F$")

# %%
def A_IRLS(X, U0, V0, cmp_loss=False, L_star=None):
    
    d = U0.shape[0]
    r = U0.shape[1]
    n = V0.shape[0]
    
    norm_list = []
    Wu_list = np.ones((d, n))
    Wv_list = np.ones((n, d))
    
    
    if cmp_loss:
        norm_list.append(np.linalg.norm(np.dot(U0, V0.T)-L_star, ord=2))
    
    Tnum = 100
    iteration = 0
    delta = 0.0001
    
    for iteration in tqdm(range(Tnum)):
    
        #fix U, update V
        #every column in X, treat it as a subproblem
        for i in range(X.shape[1]):
            y = X[:,i].reshape(-1,1)
            w = Wv_list[i]
            W = diags(w)
            W = csr_matrix(W)
            beta = np.linalg.solve((U0.T)@W@U0,(U0.T)@W@y)
            V0[i,:] = beta.reshape(r)
            
            tmp = np.abs(y - np.dot(U0, beta)).reshape(y.size)
            tmp[tmp<delta] = delta
            Wv_list[i] = 1/tmp
            
        #fix V, update U
        #every column in X.T, treat it as a subproblem
        for i in range(X.T.shape[1]):
            y = X.T[:,i].reshape(-1,1)
            w = Wu_list[i]
            W = diags(w)
            W = csr_matrix(W)
            beta = np.linalg.solve((V0.T)@W@V0,(V0.T)@W@y)
            U0[i,:] = beta.reshape(r)
            
            tmp = np.abs(y - np.dot(V0, beta)).reshape(y.size)
            tmp[tmp<delta] = delta
            Wu_list[i] = 1/tmp
        
        if cmp_loss:
            norm_list.append(np.linalg.norm(np.dot(U0, V0.T)-L_star, ord=2))
    
    if cmp_loss:
        plt_converge(norm_list)
    
    return (U0, V0)

# %%
p = 0.3
S_star = create_S(p, d, n)
X = L_star + S_star

# %%
U_0 = np.random.normal(0, 1, (d, r))
V_0 = np.random.normal(0, 1, (n, r))

# %%
U_hat, V_hat = A_IRLS(X, U_0, V_0, True, L_star)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 26.93it/s]

# %% [markdown]
# ## The image dataset

# %%
image_path = "../Data/Yale-B02/"

# %%
image_name = os.listdir(image_path)
image0 = Image.open(image_path+image_name[0])
print(np.array(image0).shape)
image0
# Out:
# (192, 168)
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=168x192 at 0x7FE11BB7EF70>

# %%
image0 = np.array(image0)
n = len(image_name)
d = image0.size
r = 5

# %%
X = np.zeros((d, n))
for i in range(n):
    image = Image.open(image_path+image_name[i])
    image = np.array(image).reshape(d)
    X[:, i] = image
X.shape
# Out:
# (32256, 64)

# %%
U_0 = np.random.normal(0, 1, (d, r))
V_0 = np.random.normal(0, 1, (n, r))

# %%
U_hat, V_hat = A_IRLS(X, U_0, V_0)
# Out:
#   1%|          | 1/100 [00:11<18:22, 11.14s/it]

# %%
image0 = Image.open(image_path+image_name[0])
image0
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=168x192 at 0x7FE119F33520>

# %%
New_iamge0 = np.dot(U_hat, V_hat.T)[:,0].reshape(192, 168)
plt.imshow(New_iamge0, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1a5a1593f026> in <module>
# ----> 1 New_iamge0 = np.dot(U_hat, V_hat.T)[:,0].reshape(192, 168)
#       2 plt.imshow(New_iamge0, cmap="gray")
#
# ValueError: cannot reshape array of size 50 into shape (192,168)

# %%
S = np.array(image0) - New_iamge0
S[S<0] = 0
plt.imshow(S, cmap="gray")
